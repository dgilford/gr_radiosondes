% %% [markdown]
% # Visualizing TLS Weighting Function

% %% [markdown]
% This notebook draws in the weighting function data file and plots it. In another notebook (e.g. see ...) we visualize a shift in the weighting function, which is a key methodology in the research.

% %% [markdown]
% ## Setup

% %%
% add the path for functions
addpath('/Users/dgilford/ncar_summer_2017/gr_radiosondes/fx_library');

% %% [markdown]
% ### Load Data

% %%
weighting_fx_filepath='/Users/dgilford/ncar_summer_2017/gr_radiosondes/msu/data/tls_weighting_function.mat';
load(weighting_fx_filepath);

% %% [markdown]
% ### Plot the TLS weighting function

% %%
h1=figure(1);
set(gcf,'color','w')
set(gca,'FontSize',15)
hold on
    plot(weights,p_weights,'LineWidth',2)
    % rescale the y-axis
    pscale(p_weights,1:5:length(p_weights),[1020 10])
    xlabel('Weights')
    title('RSS channel 4 (TLS) Weighting Fx')
    grid
hold off
